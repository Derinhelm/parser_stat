# %% [markdown]
# <a href="https://colab.research.google.com/github/Derinhelm/parser_stat/blob/main/parser_running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code downloading

# %%
# !git clone https://github.com/Derinhelm/parser_stat.git
# Out:
# Cloning into 'parser_stat'...
# remote: Enumerating objects: 362, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 362 (delta 41), reused 36 (delta 19), pack-reused 292 (from 1)
# Receiving objects: 100% (362/362), 54.10 MiB | 12.38 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
import sys
sys.path.append('/content/parser_stat')

# %% [markdown]
# # Preparing

# %%
from IPython.display import clear_output

# %%
from google.colab import files

# %%
import time

# %%
# !apt install python3.10-venv
clear_output()

# %% [markdown]
# # UDPipe running

# %%
# !python3.10 -m venv udpipe_env; source udpipe_env/bin/activate; pip install spacy-udpipe==1.0.0
#clear_output()
# Out:
# Collecting spacy-udpipe==1.0.0
#   Downloading spacy_udpipe-1.0.0-py3-none-any.whl (11 kB)
# Collecting spacy<4.0.0,>=3.0.0
#   Downloading spacy-3.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 20.3 MB/s eta 0:00:00
# Collecting ufal.udpipe>=1.2.0
#   Downloading ufal.udpipe-1.3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (936 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.8/936.8 KB 53.7 MB/s eta 0:00:00
# Collecting requests<3.0.0,>=2.13.0
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 KB 7.0 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting typer-slim<1.0.0,>=0.3.0
#   Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 KB 5.9 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.4 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.13-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 KB 13.7 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting thinc<8.4.0,>=8.3.4
#   Downloading thinc-8.3.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 27.1 MB/s eta 0:00:00
# Collecting numpy>=1.19.0
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 85.8 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.4/463.4 KB 49.5 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./udpipe_env/lib/python3.10/site-packages (from spacy<4.0.0,>=3.0.0->spacy-udpipe==1.0.0) (68.1.2)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.8/204.8 KB 25.6 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting weasel<0.5.0,>=0.4.2
#   Downloading weasel-0.4.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 KB 7.3 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 KB 11.2 MB/s eta 0:00:00
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 11.8 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (795 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.1/795.1 KB 29.3 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting typing-extensions>=4.14.1
#   Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 5.8 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.2 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 KB 18.1 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.6/153.6 KB 18.1 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 KB 10.3 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 KB 9.4 MB/s eta 0:00:00
# Collecting blis<1.4.0,>=1.3.0
#   Downloading blis-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 106.9 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting click>=8.0.0
#   Downloading click-8.3.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 KB 17.4 MB/s eta 0:00:00
# Collecting smart-open<8.0.0,>=5.2.1
#   Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 KB 8.1 MB/s eta 0:00:00
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 9.4 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Collecting wrapt
#   Downloading wrapt-2.0.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 KB 16.6 MB/s eta 0:00:00
# Installing collected packages: ufal.udpipe, cymem, wrapt, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, packaging, numpy, murmurhash, MarkupSafe, idna, click, charset_normalizer, certifi, catalogue, annotated-types, typing-inspection, typer-slim, srsly, smart-open, requests, pydantic-core, preshed, jinja2, cloudpathlib, blis, pydantic, confection, weasel, thinc, spacy, spacy-udpipe
# Successfully installed MarkupSafe-3.0.3 annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 certifi-2025.10.5 charset_normalizer-3.4.4 click-8.3.0 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.11 idna-3.11 jinja2-3.1.6 murmurhash-1.0.13 numpy-2.2.6 packaging-25.0 preshed-3.0.10 pydantic-2.12.4 pydantic-core-2.41.5 requests-2.32.5 smart-open-7.5.0 spacy-3.8.8 spacy-legacy-3.0.12 spacy-loggers-1.0.5 spacy-udpipe-1.0.0 srsly-2.5.1 thinc-8.3.8 tqdm-4.67.1 typer-slim-0.20.0 typing-extensions-4.15.0 typing-inspection-0.4.2 ufal.udpipe-1.3.1.1 urllib3-2.5.0 wasabi-1.1.3 weasel-0.4.2 wrapt-2.0.1

# %%
# !source /content/udpipe_env/bin/activate; which python; \
    python3 /content/parser_stat/parser_running.py /content/parser_stat/treebank_test_sets/treebank_data.pickle udpipe
# Out:
# /content/udpipe_env/bin/python
# /content/parser_stat/treebank_test_sets/treebank_data.pickle
# udpipe
# Downloaded pre-trained UDPipe model for 'ru' language
#
#  gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
#  pud
#    0/1000
#  100/1000
#  200/1000
#  300/1000
#  400/1000
#  500/1000
#  600/1000
#  700/1000
#  800/1000
#  900/1000
#
#  syntagrus
#    0/8800
#  100/8800
#  200/8800
#  300/8800
#  400/8800
#  500/8800
#  600/8800
#  700/8800
#  800/8800
#  900/8800
# 1000/8800
# 1100/8800
# 1200/8800
# 1300/8800
# 1400/8800
# 1500/8800
# 1600/8800
# 1700/8800
# 1800/8800
# 1900/8800
# 2000/8800
# 2100/8800
# 2200/8800
# 2300/8800
# 2400/8800
# 2500/8800
# 2600/8800
# 2700/8800
# 2800/8800
# 2900/8800
# 3000/8800
# 3100/8800
# 3200/8800
# 3300/8800
# 3400/8800
# 3500/8800
# 3600/8800
# 3700/8800
# 3800/8800
# 3900/8800
# 4000/8800
# 4100/8800
# 4200/8800
# 4300/8800
# 4400/8800
# 4500/8800
# 4600/8800
# 4700/8800
# 4800/8800
# 4900/8800
# 5000/8800
# 5100/8800
# 5200/8800
# 5300/8800
# 5400/8800
# 5500/8800
# 5600/8800
# 5700/8800
# 5800/8800
# 5900/8800
# 6000/8800
# 6100/8800
# 6200/8800
# 6300/8800
# 6400/8800
# 6500/8800
# 6600/8800
# 6700/8800
# 6800/8800
# 6900/8800
# 7000/8800
# 7100/8800
# 7200/8800
# 7300/8800
# 7400/8800
# 7500/8800
# 7600/8800
# 7700/8800
# 7800/8800
# 7900/8800
# 8000/8800
# 8100/8800
# 8200/8800
# 8300/8800
# 8400/8800
# 8500/8800
# 8600/8800
# 8700/8800
#
#  poetry
#    0/728
#  100/728
#  200/728
#  300/728
#  400/728
#  500/728
#  600/728
#  700/728
#
#  taiga
#    0/881
#  100/881
#  200/881
#  300/881
#  400/881
#  500/881
#  600/881
#  700/881
#  800/881
#
# time results (s):
# gsd       : 8.886 (s)
# pud       : 16.116 (s)
# syntagrus : 120.690 (s)
# poetry    : 8.103 (s)
# taiga     : 7.938 (s)

# %%
files.download("/content/udpipe.pickle")

# %% [markdown]
# # Stanza running

# %%
# !python3.10 -m venv stanza_env; source stanza_env/bin/activate; \
    which python; pip install stanza==1.8.1; pip install torch==2.4.0 --upgrade
#clear_output()
# Out:
# /content/stanza_env/bin/python
# Collecting stanza==1.8.1
#   Downloading stanza-1.8.1-py3-none-any.whl (970 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.4/970.4 KB 8.3 MB/s eta 0:00:00
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.9 MB/s eta 0:00:00
# Collecting protobuf>=3.15.0
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 KB 21.8 MB/s eta 0:00:00
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 KB 23.5 MB/s eta 0:00:00
# Collecting torch>=1.3.0
#   Downloading torch-2.9.0-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 673.9 kB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 112.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 2.8 MB/s eta 0:00:00
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 84.6 MB/s eta 0:00:00
# Collecting nvidia-nvshmem-cu12==3.3.20
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 8.0 MB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 111.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB ? eta 0:00:00
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB ? eta 0:00:00
# Collecting nvidia-nccl-cu12==2.27.5
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 1.9 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 18.6 MB/s eta 0:00:00
# Collecting fsspec>=0.8.5
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 KB 27.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 10.7 MB/s eta 0:00:00
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB ? eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Collecting triton==3.5.0
#   Downloading triton-3.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 3.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 KB 55.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 KB 10.9 MB/s eta 0:00:00
# Collecting typing-extensions>=4.10.0
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 1.2 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 51.2 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Using cached markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, urllib3, typing-extensions, triton, tqdm, toml, sympy, protobuf, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, idna, fsspec, filelock, emoji, charset_normalizer, certifi, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, stanza
# Successfully installed MarkupSafe-3.0.3 certifi-2025.10.5 charset_normalizer-3.4.4 emoji-2.15.0 filelock-3.20.0 fsspec-2025.10.0 idna-3.11 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 protobuf-6.33.0 requests-2.32.5 stanza-1.8.1 sympy-1.14.0 toml-0.10.2 torch-2.9.0 tqdm-4.67.1 triton-3.5.0 typing-extensions-4.15.0 urllib3-2.5.0
# Collecting torch==2.4.0
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Collecting triton==3.0.0
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.6 MB/s eta 0:00:00
# Requirement already satisfied: sympy in ./stanza_env/lib/python3.10/site-packages (from torch==2.4.0) (1.14.0)
# Collecting nvidia-cusparse-cu12==12.1.0.106
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in ./stanza_env/lib/python3.10/site-packages (from torch==2.4.0) (2025.10.0)
# Collecting nvidia-cuda-runtime-cu12==12.1.105
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 KB 67.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.20.5
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in ./stanza_env/lib/python3.10/site-packages (from torch==2.4.0) (3.1.6)
# Requirement already satisfied: networkx in ./stanza_env/lib/python3.10/site-packages (from torch==2.4.0) (3.4.2)
# Requirement already satisfied: filelock in ./stanza_env/lib/python3.10/site-packages (from torch==2.4.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./stanza_env/lib/python3.10/site-packages (from torch==2.4.0) (4.15.0)
# Collecting nvidia-cusolver-cu12==11.4.5.107
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./stanza_env/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0) (12.8.93)
# Requirement already satisfied: MarkupSafe>=2.0 in ./stanza_env/lib/python3.10/site-packages (from jinja2->torch==2.4.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./stanza_env/lib/python3.10/site-packages (from sympy->torch==2.4.0) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.0
#     Uninstalling triton-3.5.0:
#       Successfully uninstalled triton-3.5.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0
#     Uninstalling torch-2.9.0:
#       Successfully uninstalled torch-2.9.0
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 torch-2.4.0 triton-3.0.0

# %%
# !source /content/stanza_env/bin/activate; which python;\
    python3 /content/parser_stat/parser_running.py /content/parser_stat/treebank_test_sets/treebank_data.pickle stanza
# Out:
# /content/stanza_env/bin/python
# /content/parser_stat/treebank_test_sets/treebank_data.pickle
# stanza
# 2025-11-09 09:00:01 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json: 386kB [00:00, 23.2MB/s]
# 2025-11-09 09:00:01 INFO: Downloaded file to /root/stanza_resources/resources.json
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/tokenize/syntagrus.pt: 100% 641k/641k [00:00<00:00, 22.6MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/pos/syntagrus_charlm.pt: 100% 38.8M/38.8M [00:00<00:00, 54.6MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/lemma/syntagrus_nocharlm.pt: 100% 13.5M/13.5M [00:00<00:00, 20.2MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/depparse/syntagrus_charlm.pt: 100% 147M/147M [00:02<00:00, 65.7MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/forward_charlm/newswiki.pt: 100% 20.0M/20.0M [00:00<00:00, 176MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/backward_charlm/newswiki.pt: 100% 20.0M/20.0M [00:00<00:00, 215MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.8.0/models/pretrain/conll17.pt: 100% 109M/109M [00:01<00:00, 61.3MB/s]
# 2025-11-09 09:00:11 INFO: Loading these models for language: ru (Russian):
# ==================================
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# ==================================
#
# 2025-11-09 09:00:11 INFO: Using device: cpu
# 2025-11-09 09:00:11 INFO: Loading: tokenize
# /content/stanza_env/lib/python3.10/site-packages/stanza/models/tokenization/trainer.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2025-11-09 09:00:13 INFO: Loading: pos
# /content/stanza_env/lib/python3.10/site-packages/stanza/models/pos/trainer.py:123: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# /content/stanza_env/lib/python3.10/site-packages/stanza/models/common/pretrain.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(self.filename, lambda storage, loc: storage)
# /content/stanza_env/lib/python3.10/site-packages/stanza/models/common/char_model.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(filename, lambda storage, loc: storage)
# 2025-11-09 09:00:13 INFO: Loading: lemma
# /content/stanza_env/lib/python3.10/site-packages/stanza/models/lemma/trainer.py:236: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2025-11-09 09:00:14 INFO: Loading: depparse
# /content/stanza_env/lib/python3.10/site-packages/stanza/models/depparse/trainer.py:186: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2025-11-09 09:00:14 INFO: Done loading processors!
#
#  gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
#  pud
#    0/1000
#  100/1000
#  200/1000
#  300/1000
#  400/1000
#  500/1000
#  600/1000
#  700/1000
#  800/1000
#  900/1000
#
#  syntagrus
#    0/8800
#  100/8800
#  200/8800
#  300/8800
#  400/8800
#  500/8800
#  600/8800
#  700/8800
#  800/8800
#  900/8800
# 1000/8800
# 1100/8800
# 1200/8800
# 1300/8800
# 1400/8800
# 1500/8800
# 1600/8800
# 1700/8800
# 1800/8800
# 1900/8800
# 2000/8800
# 2100/8800
# 2200/8800
# 2300/8800
# 2400/8800
# 2500/8800
# 2600/8800
# 2700/8800
# 2800/8800
# 2900/8800
# 3000/8800
# 3100/8800
# 3200/8800
# 3300/8800
# 3400/8800
# 3500/8800
# 3600/8800
# 3700/8800
# 3800/8800
# 3900/8800
# 4000/8800
# 4100/8800
# 4200/8800
# 4300/8800
# 4400/8800
# 4500/8800
# 4600/8800
# 4700/8800
# 4800/8800
# 4900/8800
# 5000/8800
# 5100/8800
# 5200/8800
# 5300/8800
# 5400/8800
# 5500/8800
# 5600/8800
# 5700/8800
# 5800/8800
# 5900/8800
# 6000/8800
# 6100/8800
# 6200/8800
# 6300/8800
# 6400/8800
# 6500/8800
# 6600/8800
# 6700/8800
# 6800/8800
# 6900/8800
# 7000/8800
# 7100/8800
# 7200/8800
# 7300/8800
# 7400/8800
# 7500/8800
# 7600/8800
# 7700/8800
# 7800/8800
# 7900/8800
# 8000/8800
# 8100/8800
# 8200/8800
# 8300/8800
# 8400/8800
# 8500/8800
# 8600/8800
# 8700/8800
#
#  poetry
#    0/728
#  100/728
#  200/728
#  300/728
#  400/728
#  500/728
#  600/728
#  700/728
#
#  taiga
#    0/881
#  100/881
#  200/881
#  300/881
#  400/881
#  500/881
#  600/881
#  700/881
#  800/881
#
# time results (s):
# gsd       : 394.526 (s)
# pud       : 645.704 (s)
# syntagrus : 4880.873 (s)
# poetry    : 296.156 (s)
# taiga     : 327.234 (s)

# %%
files.download("/content/stanza.pickle")

# %% [markdown]
# # Natasha running

# %%
# !python3.10 -m venv natasha_env; source natasha_env/bin/activate; \
    which python; pip install natasha==1.6.0
#clear_output()
# Out:
# /content/natasha_env/bin/python
# Collecting natasha==1.6.0
#   Using cached natasha-1.6.0-py3-none-any.whl (34.4 MB)
# Collecting ipymarkup>=0.8.0
#   Using cached ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting slovnet>=0.6.0
#   Using cached slovnet-0.6.0-py3-none-any.whl (46 kB)
# Collecting pymorphy2
#   Using cached pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# Collecting yargy>=0.16.0
#   Using cached yargy-0.16.0-py3-none-any.whl (33 kB)
# Collecting navec>=0.9.0
#   Using cached navec-0.10.0-py3-none-any.whl (23 kB)
# Collecting razdel>=0.5.0
#   Using cached razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting intervaltree>=3
#   Using cached intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Using cached pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Collecting docopt>=0.6
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dawg-python>=0.7.1
#   Using cached DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting sortedcontainers<3.0,>=2.0
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using legacy 'setup.py install' for docopt, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for intervaltree, since package 'wheel' is not installed.
# Installing collected packages: sortedcontainers, razdel, pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, numpy, intervaltree, yargy, navec, ipymarkup, slovnet, natasha
#   Running setup.py install for docopt ... done
#   Running setup.py install for intervaltree ... done
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 intervaltree-3.1.0 ipymarkup-0.9.0 natasha-1.6.0 navec-0.10.0 numpy-2.2.6 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 razdel-0.5.0 slovnet-0.6.0 sortedcontainers-2.4.0 yargy-0.16.0

# %%
# !source /content/natasha_env/bin/activate; which python; \
    python3 /content/parser_stat/parser_running.py /content/parser_stat/treebank_test_sets/treebank_data.pickle natasha
# Out:
# /content/natasha_env/bin/python
# /content/parser_stat/treebank_test_sets/treebank_data.pickle
# natasha
#
#  gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
#  pud
#    0/1000
#  100/1000
#  200/1000
#  300/1000
#  400/1000
#  500/1000
#  600/1000
#  700/1000
#  800/1000
#  900/1000
#
#  syntagrus
#    0/8800
#  100/8800
#  200/8800
#  300/8800
#  400/8800
#  500/8800
#  600/8800
#  700/8800
#  800/8800
#  900/8800
# 1000/8800
# 1100/8800
# 1200/8800
# 1300/8800
# 1400/8800
# 1500/8800
# 1600/8800
# 1700/8800
# 1800/8800
# 1900/8800
# 2000/8800
# 2100/8800
# 2200/8800
# 2300/8800
# 2400/8800
# 2500/8800
# 2600/8800
# 2700/8800
# 2800/8800
# 2900/8800
# 3000/8800
# 3100/8800
# 3200/8800
# 3300/8800
# 3400/8800
# 3500/8800
# 3600/8800
# 3700/8800
# 3800/8800
# 3900/8800
# 4000/8800
# 4100/8800
# 4200/8800
# 4300/8800
# 4400/8800
# 4500/8800
# 4600/8800
# 4700/8800
# 4800/8800
# 4900/8800
# 5000/8800
# 5100/8800
# 5200/8800
# 5300/8800
# 5400/8800
# 5500/8800
# 5600/8800
# 5700/8800
# 5800/8800
# 5900/8800
# 6000/8800
# 6100/8800
# 6200/8800
# 6300/8800
# 6400/8800
# 6500/8800
# 6600/8800
# 6700/8800
# 6800/8800
# 6900/8800
# 7000/8800
# 7100/8800
# 7200/8800
# 7300/8800
# 7400/8800
# 7500/8800
# 7600/8800
# 7700/8800
# 7800/8800
# 7900/8800
# 8000/8800
# 8100/8800
# 8200/8800
# 8300/8800
# 8400/8800
# 8500/8800
# 8600/8800
# 8700/8800
#
#  poetry
#    0/728
#  100/728
#  200/728
#  300/728
#  400/728
#  500/728
#  600/728
#  700/728
#
#  taiga
#    0/881
#  100/881
#  200/881
#  300/881
#  400/881
#  500/881
#  600/881
#  700/881
#  800/881
#
# time results (s):
# gsd       : 2.489 (s)
# pud       : 6.152 (s)
# syntagrus : 38.141 (s)
# poetry    : 4.739 (s)
# taiga     : 2.727 (s)

# %%
files.download("/content/natasha.pickle")

# %% [markdown]
# # DeepPavlov running

# %%
# !python3.10 -m venv deeppavlov_env; source deeppavlov_env/bin/activate; \
    which python; pip install deeppavlov==1.6.0
#clear_output()
# Out:
# /content/deeppavlov_env/bin/python
# Collecting deeppavlov==1.6.0
#   Using cached deeppavlov-1.6.0-py3-none-any.whl (490 kB)
# Collecting prometheus-client<=1.16.0,>=0.13.0
#   Using cached prometheus_client-0.23.1-py3-none-any.whl (61 kB)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting tqdm<4.65.0,>=4.42.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting pybind11==2.10.3
#   Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# Collecting fastapi<=0.89.1,>=0.47.0
#   Using cached fastapi-0.89.1-py3-none-any.whl (55 kB)
# Collecting pydantic<2
#   Using cached pydantic-1.10.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Collecting pandas<1.6.0,>=1.0.0
#   Using cached pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# Collecting numpy<1.24
#   Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Collecting scipy==1.10.0
#   Using cached scipy-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
# Collecting nltk<3.10.0,>=3.2.4
#   Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Collecting filelock<3.10.0,>=3.0.0
#   Using cached filelock-3.9.1-py3-none-any.whl (9.7 kB)
# Collecting requests<3.0.0,>=2.19.0
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting uvicorn<0.19.0,>=0.13.0
#   Using cached uvicorn-0.18.3-py3-none-any.whl (57 kB)
# Collecting scikit-learn<1.1.0,>=0.24
#   Using cached scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
# Collecting starlette==0.22.0
#   Using cached starlette-0.22.0-py3-none-any.whl (64 kB)
# Collecting anyio<5,>=3.4.0
#   Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Collecting joblib
#   Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Collecting click
#   Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Collecting regex>=2021.8.3
#   Using cached regex-2025.11.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting python-dateutil>=2.8.1
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting h11>=0.8
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting six>=1.5
#   Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting exceptiongroup>=1.0.2
#   Using cached exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: pytz, wheel, urllib3, typing-extensions, tqdm, threadpoolctl, sniffio, six, regex, pybind11, prometheus-client, numpy, joblib, idna, h11, filelock, click, charset_normalizer, certifi, uvicorn, scipy, requests, python-dateutil, pydantic, nltk, exceptiongroup, scikit-learn, pandas, anyio, starlette, fastapi, deeppavlov
# Successfully installed anyio-4.11.0 certifi-2025.10.5 charset_normalizer-3.4.4 click-8.3.0 deeppavlov-1.6.0 exceptiongroup-1.3.0 fastapi-0.89.1 filelock-3.9.1 h11-0.16.0 idna-3.11 joblib-1.5.2 nltk-3.9.2 numpy-1.23.5 pandas-1.5.3 prometheus-client-0.23.1 pybind11-2.10.3 pydantic-1.10.24 python-dateutil-2.9.0.post0 pytz-2025.2 regex-2025.11.3 requests-2.32.5 scikit-learn-1.0.2 scipy-1.10.0 six-1.17.0 sniffio-1.3.1 starlette-0.22.0 threadpoolctl-3.6.0 tqdm-4.64.1 typing-extensions-4.15.0 urllib3-2.5.0 uvicorn-0.18.3 wheel-0.45.1

# %%
# !source /content/deeppavlov_env/bin/activate; which python; \
    python3 /content/parser_stat/parser_running.py /content/parser_stat/treebank_test_sets/treebank_data.pickle deeppavlov
# Out:
# /content/deeppavlov_env/bin/python
# /content/parser_stat/treebank_test_sets/treebank_data.pickle
# deeppavlov
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Collecting torch<1.14.0,>=1.6.0
#   Using cached torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Requirement already satisfied: typing-extensions in ./deeppavlov_env/lib/python3.10/site-packages (from torch<1.14.0,>=1.6.0) (4.15.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Requirement already satisfied: wheel in ./deeppavlov_env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14.0,>=1.6.0) (0.45.1)
# Requirement already satisfied: setuptools in ./deeppavlov_env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14.0,>=1.6.0) (68.1.2)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1
# Ignoring transformers: markers 'python_version < "3.8"' don't match your environment
# Collecting transformers==4.30.0
#   Using cached transformers-4.30.0-py3-none-any.whl (7.2 MB)
# Requirement already satisfied: filelock in ./deeppavlov_env/lib/python3.10/site-packages (from transformers==4.30.0) (3.9.1)
# Requirement already satisfied: regex!=2019.12.17 in ./deeppavlov_env/lib/python3.10/site-packages (from transformers==4.30.0) (2025.11.3)
# Requirement already satisfied: requests in ./deeppavlov_env/lib/python3.10/site-packages (from transformers==4.30.0) (2.32.5)
# Collecting packaging>=20.0
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Collecting pyyaml>=5.1
#   Using cached pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
# Collecting huggingface-hub<1.0,>=0.14.1
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Requirement already satisfied: numpy>=1.17 in ./deeppavlov_env/lib/python3.10/site-packages (from transformers==4.30.0) (1.23.5)
# Requirement already satisfied: tqdm>=4.27 in ./deeppavlov_env/lib/python3.10/site-packages (from transformers==4.30.0) (4.64.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Collecting safetensors>=0.3.1
#   Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./deeppavlov_env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (4.15.0)
# Collecting hf-xet<2.0.0,>=1.1.3
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Requirement already satisfied: certifi>=2017.4.17 in ./deeppavlov_env/lib/python3.10/site-packages (from requests->transformers==4.30.0) (2025.10.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./deeppavlov_env/lib/python3.10/site-packages (from requests->transformers==4.30.0) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in ./deeppavlov_env/lib/python3.10/site-packages (from requests->transformers==4.30.0) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./deeppavlov_env/lib/python3.10/site-packages (from requests->transformers==4.30.0) (3.4.4)
# Installing collected packages: tokenizers, safetensors, pyyaml, packaging, hf-xet, fsspec, huggingface-hub, transformers
# Successfully installed fsspec-2025.10.0 hf-xet-1.2.0 huggingface-hub-0.36.0 packaging-25.0 pyyaml-6.0.3 safetensors-0.6.2 tokenizers-0.13.3 transformers-4.30.0
# Collecting pytorch-crf==0.7.*
#   Using cached pytorch_crf-0.7.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2
# Collecting ufal.chu-liu-edmonds
#   Using cached ufal.chu_liu_edmonds-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
# Installing collected packages: ufal.chu-liu-edmonds
# Successfully installed ufal.chu-liu-edmonds-1.0.3
# 2025-11-09 11:19:22.472 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/morpho_tagger/UD2.3/ru_syntagrus.tar.gz download because of matching hashes
# 2025-11-09 11:19:32.878 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/syntax_parsing/rus_6layers.tar.gz download because of matching hashes
# /content/deeppavlov_env/lib/python3.10/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2025-11-09 11:19:40.688 WARNING in 'deeppavlov.core.models.torch_model'['torch_model'] at line 96: Unable to place component TorchTransformersSyntaxParser on GPU, since no CUDA GPUs are available. Using CPU.
#
#  gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
#  pud
#    0/1000
#  100/1000
#  200/1000
#  300/1000
#  400/1000
#  500/1000
#  600/1000
#  700/1000
#  800/1000
#  900/1000
#
#  syntagrus
#    0/8800
#  100/8800
#  200/8800
#  300/8800
#  400/8800
#  500/8800
#  600/8800
#  700/8800
#  800/8800
#  900/8800
# 1000/8800
# 1100/8800
# 1200/8800
# 1300/8800
# 1400/8800
# 1500/8800
# 1600/8800
# 1700/8800
# 1800/8800
# 1900/8800
# 2000/8800
# 2100/8800
# 2200/8800
# 2300/8800
# 2400/8800
# 2500/8800
# 2600/8800
# 2700/8800
# 2800/8800
# 2900/8800
# 3000/8800
# 3100/8800
# 3200/8800
# 3300/8800
# 3400/8800
# 3500/8800
# 3600/8800
# 3700/8800
# 3800/8800
# 3900/8800
# 4000/8800
# 4100/8800
# 4200/8800
# 4300/8800
# 4400/8800
# 4500/8800
# 4600/8800
# 4700/8800
# 4800/8800
# 4900/8800
# 5000/8800
# 5100/8800
# 5200/8800
# 5300/8800
# 5400/8800
# 5500/8800
# 5600/8800
# 5700/8800
# 5800/8800
# 5900/8800
# 6000/8800
# 6100/8800
# 6200/8800
# 6300/8800
# 6400/8800
# 6500/8800
# 6600/8800
# 6700/8800
# 6800/8800
# 6900/8800
# 7000/8800
# 7100/8800
# 7200/8800
# 7300/8800
# 7400/8800
# 7500/8800
# 7600/8800
# 7700/8800
# 7800/8800
# 7900/8800
# 8000/8800
# 8100/8800
# 8200/8800
# 8300/8800
# 8400/8800
# 8500/8800
# 8600/8800
# 8700/8800
#
#  poetry
#    0/728
#  100/728
#  200/728
#  300/728
#  400/728
#  500/728
#  600/728
#  700/728
#
#  taiga
#    0/881
#  100/881
#  200/881
#  300/881
#  400/881
#  500/881
#  600/881
#  700/881
#  800/881
#
# time results (s):
# gsd       : 100.601 (s)
# pud       : 147.075 (s)
# syntagrus : 1287.044 (s)
# poetry    : 99.795 (s)
# taiga     : 111.868 (s)

# %%
files.download("/content/deeppavlov.pickle")

# %% [markdown]
# # spacy running

# %%
# !python3.10 -m venv spacy_env; source spacy_env/bin/activate; \
    which python; pip install spacy==3.7.5
#clear_output()
# Out:
# /content/spacy_env/bin/python
# Collecting spacy==3.7.5
#   Using cached spacy-3.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (795 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting typer<1.0.0,>=0.3.0
#   Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Collecting numpy>=1.19.0
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.13-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
# Collecting packaging>=20.0
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# Collecting thinc<8.3.0,>=8.2.2
#   Using cached thinc-8.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (922 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
# Collecting tqdm<5.0.0,>=4.38.0
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting weasel<0.5.0,>=0.1.0
#   Using cached weasel-0.4.2-py3-none-any.whl (50 kB)
# Collecting requests<3.0.0,>=2.13.0
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in ./spacy_env/lib/python3.10/site-packages (from spacy==3.7.5) (68.1.2)
# Collecting language-data>=1.2
#   Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Using cached pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting typing-extensions>=4.14.1
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting numpy>=1.19.0
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Collecting rich>=10.11.0
#   Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting click>=8.0.0
#   Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Collecting smart-open<8.0.0,>=5.2.1
#   Using cached smart_open-7.5.0-py3-none-any.whl (63 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Collecting typer-slim<1.0.0,>=0.3.0
#   Using cached typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Collecting MarkupSafe>=2.0
#   Using cached markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Collecting marisa-trie>=1.1.0
#   Using cached marisa_trie-1.3.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Collecting wrapt
#   Using cached wrapt-2.0.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (113 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, shellingham, pygments, packaging, numpy, murmurhash, mdurl, MarkupSafe, marisa-trie, idna, click, charset_normalizer, certifi, catalogue, annotated-types, typing-inspection, typer-slim, srsly, smart-open, requests, pydantic-core, preshed, markdown-it-py, language-data, jinja2, cloudpathlib, blis, rich, pydantic, langcodes, typer, confection, weasel, thinc, spacy
# Successfully installed MarkupSafe-3.0.3 annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 certifi-2025.10.5 charset_normalizer-3.4.4 click-8.3.0 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.11 idna-3.11 jinja2-3.1.6 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.3.1 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.13 numpy-1.26.4 packaging-25.0 preshed-3.0.10 pydantic-2.12.4 pydantic-core-2.41.5 pygments-2.19.2 requests-2.32.5 rich-14.2.0 shellingham-1.5.4 smart-open-7.5.0 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.2.5 tqdm-4.67.1 typer-0.20.0 typer-slim-0.20.0 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.5.0 wasabi-1.1.3 weasel-0.4.2 wrapt-2.0.1

# %%
# !source /content/spacy_env/bin/activate; which python; python -m spacy download ru_core_news_lg; \
    python3 /content/parser_stat/parser_running.py /content/parser_stat/treebank_test_sets/treebank_data.pickle spacy
# Out:
# /content/spacy_env/bin/python
# Collecting ru-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_lg-3.7.0/ru_core_news_lg-3.7.0-py3-none-any.whl (513.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 MB 498.8 kB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0
#   Using cached pymorphy3-2.0.6-py3-none-any.whl (53 kB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in ./spacy_env/lib/python3.10/site-packages (from ru-core-news-lg==3.7.0) (3.7.5)
# Collecting dawg2-python>=0.8.0
#   Using cached dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Collecting pymorphy3-dicts-ru
#   Using cached pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.5.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.1.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.20.0)
# Requirement already satisfied: numpy>=1.19.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.26.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.32.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.0.11)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.0.13)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (25.0)
# Requirement already satisfied: setuptools in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (68.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.12.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (4.67.1)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (8.2.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: jinja2 in ./spacy_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.0 in ./spacy_env/lib/python3.10/site-packages (from dawg2-python>=0.8.0->pymorphy3>=1.0.0->ru-core-news-lg==3.7.0) (4.15.0)
# Requirement already satisfied: language-data>=1.2 in ./spacy_env/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./spacy_env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./spacy_env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in ./spacy_env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.41.5)
# Requirement already satisfied: certifi>=2017.4.17 in ./spacy_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2025.10.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./spacy_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./spacy_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./spacy_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.5.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./spacy_env/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./spacy_env/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in ./spacy_env/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./spacy_env/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (14.2.0)
# Requirement already satisfied: click>=8.0.0 in ./spacy_env/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (8.3.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./spacy_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (7.5.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./spacy_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.23.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in ./spacy_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./spacy_env/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (3.0.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./spacy_env/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./spacy_env/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./spacy_env/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.19.2)
# Requirement already satisfied: wrapt in ./spacy_env/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (2.0.1)
# Requirement already satisfied: mdurl~=0.1 in ./spacy_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-lg==3.7.0) (0.1.2)
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3, ru-core-news-lg
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.6 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-lg-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')
# /content/parser_stat/treebank_test_sets/treebank_data.pickle
# spacy
#
#  gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
#  pud
#    0/1000
#  100/1000
#  200/1000
#  300/1000
#  400/1000
#  500/1000
#  600/1000
#  700/1000
#  800/1000
#  900/1000
#
#  syntagrus
#    0/8800
#  100/8800
#  200/8800
#  300/8800
#  400/8800
#  500/8800
#  600/8800
#  700/8800
#  800/8800
#  900/8800
# 1000/8800
# 1100/8800
# 1200/8800
# 1300/8800
# 1400/8800
# 1500/8800
# 1600/8800
# 1700/8800
# 1800/8800
# 1900/8800
# 2000/8800
# 2100/8800
# 2200/8800
# 2300/8800
# 2400/8800
# 2500/8800
# 2600/8800
# 2700/8800
# 2800/8800
# 2900/8800
# 3000/8800
# 3100/8800
# 3200/8800
# 3300/8800
# 3400/8800
# 3500/8800
# 3600/8800
# 3700/8800
# 3800/8800
# 3900/8800
# 4000/8800
# 4100/8800
# 4200/8800
# 4300/8800
# 4400/8800
# 4500/8800
# 4600/8800
# 4700/8800
# 4800/8800
# 4900/8800
# 5000/8800
# 5100/8800
# 5200/8800
# 5300/8800
# 5400/8800
# 5500/8800
# 5600/8800
# 5700/8800
# 5800/8800
# 5900/8800
# 6000/8800
# 6100/8800
# 6200/8800
# 6300/8800
# 6400/8800
# 6500/8800
# 6600/8800
# 6700/8800
# 6800/8800
# 6900/8800
# 7000/8800
# 7100/8800
# 7200/8800
# 7300/8800
# 7400/8800
# 7500/8800
# 7600/8800
# 7700/8800
# 7800/8800
# 7900/8800
# 8000/8800
# 8100/8800
# 8200/8800
# 8300/8800
# 8400/8800
# 8500/8800
# 8600/8800
# 8700/8800
#
#  poetry
#    0/728
#  100/728
#  200/728
#  300/728
#  400/728
#  500/728
#  600/728
#  700/728
#
#  taiga
#    0/881
#  100/881
#  200/881
#  300/881
#  400/881
#  500/881
#  600/881
#  700/881
#  800/881
#
# time results (s):
# gsd       : 10.477 (s)
# pud       : 18.776 (s)
# syntagrus : 150.389 (s)
# poetry    : 10.597 (s)
# taiga     : 11.303 (s)

# %%
files.download("/content/spacy.pickle")
