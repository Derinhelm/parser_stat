# %% [markdown]
# <a href="https://colab.research.google.com/github/Derinhelm/parser_stat/blob/parser_speed/parser_speed_running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Загрузка репозитория

# %%
# !rm -r /content/parser_stat/

# %%
# !git clone -b parser_speed https://github.com/Derinhelm/parser_stat.git
# Out:
# Cloning into 'parser_stat'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 342 (delta 32), reused 23 (delta 15), pack-reused 292 (from 1)
# Receiving objects: 100% (342/342), 53.59 MiB | 24.52 MiB/s, done.
# Resolving deltas: 100% (187/187), done.

# %% [markdown]
# # spacy

# %%
# !pip install spacy==3.7.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 kB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 74.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: blis
#     Found existing installation: blis 1.3.0
#     Uninstalling blis-1.3.0:
#       Successfully uninstalled blis-1.3.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.3.6
#     Uninstalling thinc-8.3.6:
#       Successfully uninstalled thinc-8.3.6
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.8.7
#     Uninstalling spacy-3.8.7:
# ...

# %%
# !python3 -m spacy download ru_core_news_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 MB 824.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 107.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !python3 /content/parser_stat/speed_scripts/parser_running_pickle_od.py /content/parser_stat/treebank_test_sets/treebank_data.pickle /content/parser_stat/speed_scripts/spacy_config.yaml spacy
# Out:
# Processing corpus: gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
# Processing corpus: pud
#    0/1000
# Traceback (most recent call last):
#   File "/content/parser_stat/speed_scripts/parser_running_pickle_od.py", line 168, in <module>
#     profile_f(sent, parser_instance, treebank_name, args.parser_name, i, config_file)
#   File "/content/parser_stat/speed_scripts/parser_running_pickle_od.py", line 115, in profile_f
#     _ = parser.parse(sent.text)
#         ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/parser_stat/speed_scripts/parser_running_pickle_od.py", line 21, in parse
#     parsing_res = self.nlp(sent)
#                   ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/spacy/language.py", line 1049, in __call__
#     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# # Natasha

# %%
# !pip install natasha==1.6.0
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 127.8 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=998a82e34da5357180845595e924ba02253b0be794c87cb54de03e915ed78cf2
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# ...
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26098 sha256=a6eee51acfcb6a9b6829f4759362c5a26481a39f880d48523639d21e3ad3b110
#   Stored in directory: /root/.cache/pip/wheels/65/c3/c3/238bf93c243597857edd94ddb0577faa74a8e16e9585896e83
# Successfully built docopt intervaltree
# ...

# %%
# !python3 /content/parser_stat/speed_scripts/parser_running_pickle_od.py /content/parser_stat/treebank_test_sets/treebank_data.pickle /content/parser_stat/speed_scripts/natasha_config.yaml natasha
# Out:
# Processing corpus: gsd
#    0/601
#  100/601
#  200/601
#  300/601
#  400/601
#  500/601
#  600/601
#
# Processing corpus: pud
#    0/1000
#  100/1000
#  200/1000
#  300/1000
#  400/1000
#  500/1000
#  600/1000
#  700/1000
#  800/1000
#  900/1000
#
# Processing corpus: syntagrus
#    0/8800
#  100/8800
#  200/8800
#  300/8800
#  400/8800
#  500/8800
#  600/8800
#  700/8800
#  800/8800
#  900/8800
# 1000/8800
# 1100/8800
# 1200/8800
# 1300/8800
# 1400/8800
# 1500/8800
# 1600/8800
# 1700/8800
# 1800/8800
# 1900/8800
# 2000/8800
# 2100/8800
# 2200/8800
# 2300/8800
# 2400/8800
# 2500/8800
# 2600/8800
# 2700/8800
# 2800/8800
# 2900/8800
# 3000/8800
# 3100/8800
# 3200/8800
# 3300/8800
# 3400/8800
# 3500/8800
# 3600/8800
# 3700/8800
# 3800/8800
# 3900/8800
# 4000/8800
# 4100/8800
# 4200/8800
# 4300/8800
# 4400/8800
# 4500/8800
# 4600/8800
# 4700/8800
# 4800/8800
# 4900/8800
# 5000/8800
# 5100/8800
# 5200/8800
# 5300/8800
# 5400/8800
# 5500/8800
# 5600/8800
# 5700/8800
# 5800/8800
# ...

# %%
import pickle
with open('/content/natasha_profiling_test.pickle', 'rb') as f:
    data_new = pickle.load(f)

# %%
data_new['gsd'][0]
# Out:
# OrderedDict([('sent_id', 'test-s1'),
#              ('total_time', 0.0075436352),
#              ('profiling_data',
#               {'doc.py:138 (parse_syntax)': 0.0,
#                'infer.py:81 (__call__)': 0.0,
#                'model.py:277 (__call__)': 0.0,
#                'model.py:397 (decode)': 0.0,
#                'navec:60:load': 0.0})])

# %% [markdown]
# # Stanza

# %%
# !pip install stanza==1.8.1
# !pip install torch==2.4.0 --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 100.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !python3 /content/parser_stat/speed_scripts/parser_running_pickle_od.py /content/parser_stat/treebank_test_sets/treebank_data.pickle /content/parser_stat/speed_scripts/stanza_config.yaml stanza
# Out:
# 2025-10-13 22:23:12 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2025-10-13 22:23:12 INFO: Downloaded file to /root/stanza_resources/resources.json
# 2025-10-13 22:23:13 INFO: Loading these models for language: ru (Russian):
# ...
# | Processor | Package            |
# ----------------------------------
# | tokenize  | syntagrus          |
# | pos       | syntagrus_charlm   |
# | lemma     | syntagrus_nocharlm |
# | depparse  | syntagrus_charlm   |
# ...
#
# 2025-10-13 22:23:13 INFO: Using device: cpu
# 2025-10-13 22:23:13 INFO: Loading: tokenize
# ...
